# %%
import pandas as pd

# %%
url = "https://datamb.football/database/CURRENT/RATOP72526/CB/CB.xlsx"

df = pd.read_excel(url)

df.head()
# Out:
#         Player Team within selected timeframe  Age  Minutes played  \
# 0   M. Valjent                       Mallorca   30            2002
# 1   F. Lejeune                 Rayo Vallecano   34            1965
# 2   L. Cabrera                       Espanyol   34            1886
# 3  N. Tenaglia               Deportivo Alavés   29            1879
# 4        Natan                     Real Betis   24            1839
#
#    Successful defensive actions per 90  Defensive duels won, %  \
# 0                                 7.64                   61.68
# 1                                 9.11                   66.43
# 2                                 7.06                   68.83
# 3                                 8.24                   66.33
# 4                                 7.24                   72.94
#
#    Aerial duels won, %  Progressive runs per 90  Accurate forward passes, %  \
# 0                54.84                     1.30                       75.91
# ...

# %%
df.to_csv("filename.csv", index=False)
